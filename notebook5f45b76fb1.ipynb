# %%
# !git clone https://github.com/Mohammadzamanid/Spatial-LLM.git
# %cd Spatial-LLM
# !pip install -q transformers peft accelerate datasets bitsandbytes geopandas shapely mercantile pyyaml pillow
# Out:
# Cloning into 'Spatial-LLM'...
# remote: Enumerating objects: 300, done.
# remote: Counting objects: 100% (300/300), done.
# remote: Compressing objects: 100% (259/259), done.
# remote: Total 300 (delta 135), reused 51 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (300/300), 167.70 KiB | 7.62 MiB/s, done.
# Resolving deltas: 100% (135/135), done.
# /kaggle/working/Spatial-LLM
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 32.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 105.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ...

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"   # MUST be before any torch/CUDA use

# clean clone (avoid the nested Spatial-LLM/Spatial-LLM folder)
# %cd /kaggle/working
# !rm -rf Spatial-LLM
# !git clone https://github.com/Mohammadzamanid/Spatial-LLM.git
# %cd Spatial-LLM
# !git log --oneline -1   # should show 7b7b3ab
# Out:
# /kaggle/working
# Cloning into 'Spatial-LLM'...
# remote: Enumerating objects: 300, done.
# remote: Counting objects: 100% (300/300), done.
# remote: Compressing objects: 100% (259/259), done.
# remote: Total 300 (delta 135), reused 51 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (300/300), 167.70 KiB | 8.83 MiB/s, done.
# Resolving deltas: 100% (135/135), done.
# /kaggle/working/Spatial-LLM
# 7b7b3ab (HEAD -> main, origin/main, origin/HEAD) fix: dtype mismatch (Half vs Float) + DataParallel on T4 x2

# %%
# !python -m src.data.real_datasets --dataset cities15000 --n_train 8000 --n_val 1000
# !CUDA_VISIBLE_DEVICES=0 python -m src.training.trainer --config configs/train_config.yaml
# Out:
# INFO:__main__:Downloading https://download.geonames.org/export/dump/cities15000.zip ...
# INFO:__main__:Extracted → data/raw/cities15000.txt
# INFO:__main__:Parsed 33,744 real cities from cities15000
# INFO:__main__:Wrote 8,000 real QA pairs → data/processed/train.jsonl
# INFO:__main__:Wrote 1,000 real QA pairs → data/processed/val.jsonl
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/Qwen/Qwen2.5-1.5B/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/Qwen/Qwen2.5-1.5B/8faed761d45a263340a0528343f099c05c9a4323/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/Qwen/Qwen2.5-1.5B/8faed761d45a263340a0528343f099c05c9a4323/config.json "HTTP/1.1 200 OK"
# config.json: 100%|█████████████████████████████| 684/684 [00:00<00:00, 2.82MB/s]
# ...

# %%
# !cp -r outputs /kaggle/working/spatial-llm-outputs && echo "saved checkpoint"
# Out:
# saved checkpoint
